# %% [markdown]
# <a href="https://colab.research.google.com/github/Shreyash0079/DEEP-LEARNING/blob/main/EWMA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Welcome to Colab!

# %%
import pandas as pd
import  numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("/content/temperature_data_114_rows.csv")

# %%
df.head()
# Out:
#          date  meantemp
# 0  2017-01-01     15.00
# 1  2017-01-02     15.47
# 2  2017-01-03     15.94
# 3  2017-01-04     16.41
# 4  2017-01-05     16.88

# %%
plt.scatter(df["date"],df["meantemp"],color="red")

# %%
x1=df["meantemp"].ewm(alpha=0.6).mean()

# %%
x1
# Out:
# 0      15.000000
# 1      15.427273
# 2      15.889189
# 3      16.357966
# 4      16.827801
#          ...
# 109    34.677799
# 110    35.147780
# 111    35.617778
# 112    34.197778
# 113    34.478778
# Name: meantemp, Length: 114, dtype: float64

# %%
df["ewma"] = x1
df
# Out:
#            date  meantemp       ewma
# 0    2017-01-01     15.00  15.000000
# 1    2017-01-02     15.47  15.335714
# 2    2017-01-03     15.94  15.723077
# 3    2017-01-04     16.41  16.146059
# 4    2017-01-05     16.88  16.590980
# ..          ...       ...        ...
# 109  2017-04-20     34.73  34.438206
# 110  2017-04-21     35.20  34.895282
# 111  2017-04-22     35.67  35.360113
# 112  2017-04-23     34.04  34.568045
# 113  2017-04-24     34.51  34.533218
#
# [114 rows x 3 columns]

# %%
plt.scatter(df["date"],df["meantemp"],color="red")
plt.plot(df["date"],x1,color="black",label="appha=0.9")
plt.legend()
plt.show()
